# %% [markdown]
# #CHEATSHEETS

# %% [markdown]
# ![cheatsheets-1.webp](data:image/webp;base64,...)

# %% [markdown]
# ![cheatsheets-2.webp](data:image/webp;base64,...)

# %% [markdown]
# #HANDOUT

# %% [markdown]
# # 1.)  BEGGİNERS HANDOUT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2.) İNTERMEDİATE HANDOUT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3.) TİPS HANDOUT

# %% [markdown]
# ![image.png](data:image/png;base64,...)
